// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания №5

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс Book в C#, который будет представлять информацию о
// книгах. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.
// Требования к базовому классу Book:
// • Атрибуты: Название (Title), Автор (Author), Год издания (YearOfPublication).
// • Методы:
// o GetInfo(): метод для получения информации о книге в виде строки.
// o Read(): метод для вывода сообщения о чтении книги.
// o Borrow(): метод для вывода сообщения о выдаче книги на чтение.
// Требования к производным классам:
// 1. Учебник (Textbook): Должен содержать дополнительные атрибуты, такие как
// Предмет (Subject). Метод Read() должен быть переопределен для
// добавления информации о предмете при чтении учебника.
// 2. Художественная литература (Fiction): Должен содержать дополнительные
// атрибуты, такие как Жанр (Genre). Метод Borrow() должен быть
// переопределен для добавления информации о жанре при выдаче книги на
// чтение.
// 3. Научная литература (ScientificLiterature) (если требуется третий класс):
// Должен содержать дополнительные атрибуты, такие как Область науки
// (FieldOfScience). Метод GetInfo() должен быть переопределен для включения
// информации об области науки в описании книги.

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public class Book
{
    // Атрибуты
    public string Title { get; set; }
    public string Author { get; set; }
    public int YearOfPublication { get; set; }

    // Конструктор
    public Book(string title, string author, int yearOfPublication)
    {
        Title = title;
        Author = author;
        YearOfPublication = yearOfPublication;
    }

    // Методы
    public virtual string GetInfo()
    {
        return $"Книга: '{Title}', Автор: {Author}, Год издания: {YearOfPublication}";
    }

    public virtual void Read()
    {
        Console.WriteLine($"Чтение книги: '{Title}'");
    }

    public virtual void Borrow()
    {
        Console.WriteLine($"Книга '{Title}' выдана на чтение");
    }
}

// Производный класс Textbook (Учебник)
public class Textbook : Book
{
    // Дополнительный атрибут
    public string Subject { get; set; }

    // Конструктор
    public Textbook(string title, string author, int yearOfPublication, string subject) 
        : base(title, author, yearOfPublication)
    {
        Subject = subject;
    }

    // Переопределение метода Read()
    public override void Read()
    {
        Console.WriteLine($"Изучение учебника по предмету '{Subject}': '{Title}'");
    }

    // Переопределение метода GetInfo()
    public override string GetInfo()
    {
        return base.GetInfo() + $", Предмет: {Subject}";
    }
}

// Производный класс Fiction (Художественная литература)
public class Fiction : Book
{
    // Дополнительный атрибут
    public string Genre { get; set; }

    // Конструктор
    public Fiction(string title, string author, int yearOfPublication, string genre) 
        : base(title, author, yearOfPublication)
    {
        Genre = genre;
    }

    // Переопределение метода Borrow()
    public override void Borrow()
    {
        Console.WriteLine($"Художественная книга в жанре '{Genre}': '{Title}' выдана для удовольствия чтения");
    }

    // Переопределение метода GetInfo()
    public override string GetInfo()
    {
        return base.GetInfo() + $", Жанр: {Genre}";
    }
}

// Производный класс ScientificLiterature (Научная литература)
public class ScientificLiterature : Book
{
    // Дополнительный атрибут
    public string FieldOfScience { get; set; }

    // Конструктор
    public ScientificLiterature(string title, string author, int yearOfPublication, string fieldOfScience) 
        : base(title, author, yearOfPublication)
    {
        FieldOfScience = fieldOfScience;
    }

    // Переопределение метода GetInfo()
    public override string GetInfo()
    {
        return base.GetInfo() + $", Область науки: {FieldOfScience}";
    }

    // Переопределение метода Read()
    public override void Read()
    {
        Console.WriteLine($"Исследование научной работы в области '{FieldOfScience}': '{Title}'");
    }
}

// Демонстрация работы классов
public class LibraryDemo
{
    public static void Demonstrate()
    {

        // Создание объектов разных типов книг
        Book[] books = new Book[]
        {
            new Book("Искусство алгоритмов", "Максим Козлов", 2022),
            new Textbook("Химия для продвинутых", "Елена Смирнова", 2021, "Химия"),
            new Fiction("Тайна семи замков", "Алексей Волков", 2018, "Фэнтези"),
            new ScientificLiterature("Космические исследования", "Дмитрий Орлов", 2019, "Астрономия"),
            new Fiction("Берег туманов", "Мария Иванова", 2020, "Детектив")
        };

        // Демонстрация полиморфизма
        foreach (var book in books)
        {
            Console.WriteLine(book.GetInfo());
            book.Read();
            book.Borrow();
            Console.WriteLine();
        }

    }
}

// Запуск демонстрации
LibraryDemo.Demonstrate();
// Out:
// Книга: 'Искусство алгоритмов', Автор: Максим Козлов, Год издания: 2022
// Чтение книги: 'Искусство алгоритмов'
// Книга 'Искусство алгоритмов' выдана на чтение
//
// Книга: 'Химия для продвинутых', Автор: Елена Смирнова, Год издания: 2021, Предмет: Химия
// Изучение учебника по предмету 'Химия': 'Химия для продвинутых'
// Книга 'Химия для продвинутых' выдана на чтение
//
// Книга: 'Тайна семи замков', Автор: Алексей Волков, Год издания: 2018, Жанр: Фэнтези
// Чтение книги: 'Тайна семи замков'
// Художественная книга в жанре 'Фэнтези': 'Тайна семи замков' выдана для удовольствия чтения
//
// Книга: 'Космические исследования', Автор: Дмитрий Орлов, Год издания: 2019, Область науки: Астрономия
// Исследование научной работы в области 'Астрономия': 'Космические исследования'
// Книга 'Космические исследования' выдана на чтение
//
// Книга: 'Берег туманов', Автор: Мария Иванова, Год издания: 2020, Жанр: Детектив
// Чтение книги: 'Берег туманов'
// Художественная книга в жанре 'Детектив': 'Берег туманов' выдана для удовольствия чтения
